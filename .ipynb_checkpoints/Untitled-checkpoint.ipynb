# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
# read in csv files
engine = create_engine('postgresql://postgres:postgres@localhost:5432/AirlineETL')
connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "<pg_user>"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-26-313799e92ce8> in <module>()
#       1 # read in csv files
#       2 engine = create_engine('postgresql://<pg_user>:<pg_pw>@localhost:5432/AirlineETL')
# ----> 3 connection = engine.connect()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in connect(self, **kwargs)
#    2261         """
#    2262
# -> 2263         return self._connection_cls(self, **kwargs)
#    2264
#    2265     @util.deprecated(
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     102                 connection
#     103                 if connection is not None
# --> 104                 else engine.raw_connection()
#     105             )
#     106             self.__transaction = None
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    2368         """
#    2369         return self._wrap_pool_connect(
# -> 2370             self.pool.unique_connection, _connection
#    2371         )
#    2372
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338             if connection is None:
#    2339                 Connection._handle_dbapi_exception_noconnection(
# -> 2340                     e, dialect, self
#    2341                 )
#    2342             else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582         elif should_wrap:
#    1583             util.raise_(
# -> 1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#    1586         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     302
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#     306     def _create_connection(self):
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#      72         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#      72         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     506     def connect(self, *cargs, **cparams):
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#     510     def create_connect_args(self, url):
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "<pg_user>"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# read in csv files
airport_info = pd.read_csv("Data/airports.csv")
countries_info = pd.read_csv("Data/countries.csv")
route_info = pd.read_csv("Data/routes.csv")

# %%
# create dataframe and drop unnecessary columns
route_df = route_info.drop(columns=[" codeshare", " stops"])

# rename columns
route_df.rename(columns={
    'airline ID': "airline_id",
    ' source airport': "source_airport",
    ' source airport id': "source_airport_id",
    ' destination apirport': "destination_airport",
    ' destination airport id': "destination_airport_id",
    ' equipment': "equipment"
}, inplace=True)

route_df
# Out:
#       airline airline_id source_airport source_airport_id destination_airport  \
# 0          2B        410            AER              2965                 KZN
# 1          2B        410            ASF              2966                 KZN
# 2          2B        410            ASF              2966                 MRV
# 3          2B        410            CEK              2968                 KZN
# 4          2B        410            CEK              2968                 OVB
# ...       ...        ...            ...               ...                 ...
# 67658      ZL       4178            WYA              6334                 ADL
# 67659      ZM      19016            DME              4029                 FRU
# 67660      ZM      19016            FRU              2912                 DME
# 67661      ZM      19016            FRU              2912                 OSS
# 67662      ZM      19016            OSS              2913                 FRU
#
#       destination_airport_id equipment
# 0                       2990       CR2
# 1                       2990       CR2
# 2                       2962       CR2
# 3                       2990       CR2
# 4                       4078       CR2
# ...                      ...       ...
# 67658                   3341       SF3
# 67659                   2912       734
# 67660                   4029       734
# 67661                   2913       734
# 67662                   2912       734
#
# [67663 rows x 7 columns]

# %%
route_df = route_df.loc[(route_df["airline_id"] != 'N') &
                        (route_df["source_airport"] != 'N') &
                        (route_df["source_airport"] != 'ABJ') &
                        (route_df["source_airport"] != 'TXL') &
                        (route_df["source_airport"] != 'ETH') &
                        (route_df["source_airport"] != 'SXF') &
                        (route_df["source_airport"] != 'RTW') &
                        (route_df["source_airport"] != 'MRE') &
                        (route_df["source_airport"] != 'WDH') &
                        (route_df["source_airport"] != 'ISN') &
                        (route_df["source_airport"] != 'DOK') &
                        (route_df["source_airport"] != 'SHP') &
                        (route_df["source_airport"] != 'KCG') &
                        (route_df["source_airport"] != 'KQA') &
                        (route_df["source_airport"] != 'SDV') &
                        (route_df["source_airport"] != 'WVB') &
                        (route_df["source_airport"] != 'ERS') &
                        (route_df["source_airport"] != 'LUD') &
                        (route_df["source_airport"] != 'MPA') &
                        (route_df["source_airport"] != 'NVK') &
                        (route_df["destination_airport"] != 'N') &
                        (route_df["destination_airport"] != 'ABJ') &
                        (route_df["destination_airport"] != 'TXL') &
                        (route_df["destination_airport"] != 'ETH') &
                        (route_df["destination_airport"] != 'SXF') &
                        (route_df["destination_airport"] != 'RTW') &
                        (route_df["destination_airport"] != 'MRE') &
                        (route_df["destination_airport"] != 'WDH') &
                        (route_df["destination_airport"] != 'ISN') &
                        (route_df["destination_airport"] != 'DOK') &
                        (route_df["destination_airport"] != 'SHP') &
                        (route_df["destination_airport"] != 'KCG') &
                        (route_df["destination_airport"] != 'KQA') &
                        (route_df["destination_airport"] != 'SDV') &
                        (route_df["destination_airport"] != 'WVB') &
                        (route_df["destination_airport"] != 'ERS') &
                        (route_df["destination_airport"] != 'LUD') &
                        (route_df["destination_airport"] != 'MPA') &
                        (route_df["destination_airport"] != 'NVK') &
                        (route_df["destination_airport_id"] != 'N') &
                        (route_df["source_airport_id"] != 'N')]

route_df = route_df.dropna(how='any')

route_df
# Out:
#       airline airline_id source_airport source_airport_id destination_airport  \
# 0          2B        410            AER              2965                 KZN
# 1          2B        410            ASF              2966                 KZN
# 2          2B        410            ASF              2966                 MRV
# 3          2B        410            CEK              2968                 KZN
# 4          2B        410            CEK              2968                 OVB
# ...       ...        ...            ...               ...                 ...
# 67658      ZL       4178            WYA              6334                 ADL
# 67659      ZM      19016            DME              4029                 FRU
# 67660      ZM      19016            FRU              2912                 DME
# 67661      ZM      19016            FRU              2912                 OSS
# 67662      ZM      19016            OSS              2913                 FRU
#
#       destination_airport_id equipment
# 0                       2990       CR2
# 1                       2990       CR2
# 2                       2962       CR2
# 3                       2990       CR2
# 4                       4078       CR2
# ...                      ...       ...
# 67658                   3341       SF3
# 67659                   2912       734
# 67660                   4029       734
# 67661                   2913       734
# 67662                   2912       734
#
# [65933 rows x 7 columns]

# %%
# Use pandas to load csv converted DataFrame into database
route_df.to_sql(name='airline_routes', con=engine, if_exists='append', index=False)

# Use pandas to load json converted DataFrame into database
#new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "<pg_user>"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-7-0252af288815> in <module>()
#       1 # Use pandas to load csv converted DataFrame into database
# ----> 2 route_df.to_sql(name='airline_routes', con=engine, if_exists='append', index=False)
#       3
#       4 # Use pandas to load json converted DataFrame into database
#       5 #new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in create(self)
#     642
#     643     def create(self):
# --> 644         if self.exists():
#     645             if self.if_exists == "fail":
#     646                 raise ValueError(f"Table '{self.name}' already exists.")
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in exists(self)
#     629
#     630     def exists(self):
# --> 631         return self.pd_sql.has_table(self.name, self.schema)
#     632
#     633     def sql_schema(self):
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1339     def has_table(self, name, schema=None):
#    1340         return self.connectable.run_callable(
# -> 1341             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1342         )
#    1343
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2209
#    2210         """
# -> 2211         with self._contextual_connect() as conn:
#    2212             return conn.run_callable(callable_, *args, **kwargs)
#    2213
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338             if connection is None:
#    2339                 Connection._handle_dbapi_exception_noconnection(
# -> 2340                     e, dialect, self
#    2341                 )
#    2342             else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582         elif should_wrap:
#    1583             util.raise_(
# -> 1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#    1586         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#      72         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#      72         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     506     def connect(self, *cargs, **cparams):
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#     510     def create_connect_args(self, url):
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "<pg_user>"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
airport_df = airport_info.drop(columns=["ident", "elevation_ft", "continent", "iso_region",
                                        "municipality", "scheduled_service", "gps_code", "local_code",
                                       "home_link", "wikipedia_link", "keywords"])

airport_df.rename(columns={
    "type": "ap_type",
    "name": "ap_name",
    "latitude_deg": "lat",
    "longitude_deg": "lng",
    "iso_country": "country_code",
}, inplace=True)

no_null_airport_df = airport_df.dropna(how='any')

no_null_airport_df = no_null_airport_df.loc[(no_null_airport_df["ap_type"] != "closed") & 
                                            (no_null_airport_df["iata_code"] != "PHM") &
                                            (no_null_airport_df["iata_code"] != "ABJ") &
                                            (no_null_airport_df["iata_code"] != "GGC") &
                                            (no_null_airport_df["iata_code"] != "CTY") &
                                            (no_null_airport_df["iata_code"] != "MRE") &
                                            (no_null_airport_df["iata_code"] != "KMM") &
                                            (no_null_airport_df["iata_code"] != "PRM") &
                                            (no_null_airport_df["iata_code"] != "DDU") &
                                            (no_null_airport_df["iata_code"] != "KQA") &
                                            (no_null_airport_df["iata_code"] != "PCO") &
                                            (no_null_airport_df["iata_code"] != "NWT")]

no_null_airport_df.duplicated(keep = 'last')
no_null_airport_df = no_null_airport_df.loc[no_null_airport_df["iata_code"].duplicated() != True]
#no_null_airport_df = no_null_airport_df.drop(columns=["duplicated"])
clean_airport_df = no_null_airport_df

#Fixing Namibian airports to be N instead of NA
#for index,row in clean_airport_df.iterrows():
#    if row['country_code'] == "NA":
#        countries_df.loc[index,"country_code"] = "N"
        
clean_airport_df
# Out:
#            id         ap_type                                  ap_name  \
# 227      4650   small_airport                           Utirik Airport
# 449      6924   small_airport                  Ocean Reef Club Airport
# 607      7063   small_airport                    Pilot Station Airport
# 686      7139   small_airport                    Crested Butte Airpark
# 1103     7545   small_airport                        LBJ Ranch Airport
# ...       ...             ...                                      ...
# 63114   27242   large_airport  Dalian Zhoushuizi International Airport
# 63115  307013  medium_airport                Tonghua Sanyuanpu Airport
# 63116   27243   large_airport   Shenyang Taoxian International Airport
# 63118   27244  medium_airport              Yanji Chaoyangchuan Airport
# 63119  317861  medium_airport                    Yingkou Lanqi Airport
#
#              lat         lng country_code iata_code
# 227    11.222000  169.852005           MH       UTK
# 449    25.325399  -80.274803           US       OCA
# 607    61.934601 -162.899994           US       PQS
# 686    38.851918 -106.928341           US       CSE
# 1103   30.251801  -98.622498           US       JCY
# ...          ...         ...          ...       ...
# 63114  38.965698  121.539001           CN       DLC
# 63115  42.253889  125.703333           CN       TNH
# 63116  41.639801  123.483002           CN       SHE
# 63118  42.882801  129.451004           CN       YNJ
# 63119  40.542524  122.358600           CN       YKH
#
# [8833 rows x 7 columns]

# %%
dups = no_null_airport_df
dups["Duplicated"] = dups["iata_code"].duplicated()
dups = dups.loc[(dups["Duplicated"] == True)]
dups
# Out:
# Empty DataFrame
# Columns: [id, ap_type, ap_name, lat, lng, country_code, iata_code, Duplicated]
# Index: []

# %%
clean_airport_df[clean_airport_df["country_code"] == 'NA']
# Out:
# Empty DataFrame
# Columns: [id, ap_type, ap_name, lat, lng, country_code, iata_code, Duplicated]
# Index: []

# %%
no_null_airport_df[no_null_airport_df["iata_code"] == 'ABJ']
# Out:
# Empty DataFrame
# Columns: [id, ap_type, ap_name, lat, lng, country_code, iata_code, Duplicated]
# Index: []

# %%
no_null_airport_df[no_null_airport_df["iata_code"] == 'GGC']
# Out:
# Empty DataFrame
# Columns: [id, ap_type, ap_name, lat, lng, country_code, iata_code, Duplicated]
# Index: []

# %%
no_null_airport_df[no_null_airport_df["iata_code"] == 'CLG']
# Out:
#           id        ap_type                         ap_name        lat  \
# 30393  19454  small_airport  New Coalinga Municipal Airport  36.163101
#
#               lng country_code iata_code  Duplicated
# 30393 -120.293999           US       CLG       False

# %%
no_null_airport_df[no_null_airport_df["iata_code"] == 'CTY']
# Out:
# Empty DataFrame
# Columns: [id, ap_type, ap_name, lat, lng, country_code, iata_code, Duplicated]
# Index: []

# %%
# Use pandas to load csv converted DataFrame into database
clean_airport_df.to_sql(name='airports', con=engine, if_exists='append', index=False)

# Use pandas to load json converted DataFrame into database
#new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "<pg_user>"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-15-89e11e18e524> in <module>()
#       1 # Use pandas to load csv converted DataFrame into database
# ----> 2 clean_airport_df.to_sql(name='airports', con=engine, if_exists='append', index=False)
#       3
#       4 # Use pandas to load json converted DataFrame into database
#       5 #new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in create(self)
#     642
#     643     def create(self):
# --> 644         if self.exists():
#     645             if self.if_exists == "fail":
#     646                 raise ValueError(f"Table '{self.name}' already exists.")
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in exists(self)
#     629
#     630     def exists(self):
# --> 631         return self.pd_sql.has_table(self.name, self.schema)
#     632
#     633     def sql_schema(self):
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1339     def has_table(self, name, schema=None):
#    1340         return self.connectable.run_callable(
# -> 1341             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1342         )
#    1343
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2209
#    2210         """
# -> 2211         with self._contextual_connect() as conn:
#    2212             return conn.run_callable(callable_, *args, **kwargs)
#    2213
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338             if connection is None:
#    2339                 Connection._handle_dbapi_exception_noconnection(
# -> 2340                     e, dialect, self
#    2341                 )
#    2342             else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582         elif should_wrap:
#    1583             util.raise_(
# -> 1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#    1586         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#      72         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#      72         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     506     def connect(self, *cargs, **cparams):
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#     510     def create_connect_args(self, url):
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "<pg_user>"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
countries_df = countries_info.drop(columns=["wikipedia_link", "keywords", "continent"])

#countries_df.rename(columns={
#    "continent": "continent_id"
#}, inplace=True)

#countries_df.dropna(how='any',inplace=True)
countries_df
# Out:
#          id code                           name
# 0    302672   AD                        Andorra
# 1    302618   AE           United Arab Emirates
# 2    302619   AF                    Afghanistan
# 3    302722   AG            Antigua and Barbuda
# 4    302723   AI                       Anguilla
# ..      ...  ...                            ...
# 242  302609   YT                        Mayotte
# 243  302610   ZA                   South Africa
# 244  302611   ZM                         Zambia
# 245  302612   ZW                       Zimbabwe
# 246  302613   ZZ  Unknown or unassigned country
#
# [247 rows x 3 columns]

# %%
countries_df["code"].value_counts

for index,row in countries_df.iterrows():
    if row[2] == "Namibia":
        countries_df.loc[index,"code"] = "N"
        
countries_df[countries_df["code"] == 'N']
# Out:
#          id code     name
# 156  302591    N  Namibia

# %%
# Use pandas to load csv converted DataFrame into database
countries_df.to_sql(name='countries', con=engine, if_exists='append', index=False)

# Use pandas to load json converted DataFrame into database
#new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "<pg_user>"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-18-68db9e84b405> in <module>()
#       1 # Use pandas to load csv converted DataFrame into database
# ----> 2 countries_df.to_sql(name='countries', con=engine, if_exists='append', index=False)
#       3
#       4 # Use pandas to load json converted DataFrame into database
#       5 #new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in create(self)
#     642
#     643     def create(self):
# --> 644         if self.exists():
#     645             if self.if_exists == "fail":
#     646                 raise ValueError(f"Table '{self.name}' already exists.")
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in exists(self)
#     629
#     630     def exists(self):
# --> 631         return self.pd_sql.has_table(self.name, self.schema)
#     632
#     633     def sql_schema(self):
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1339     def has_table(self, name, schema=None):
#    1340         return self.connectable.run_callable(
# -> 1341             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1342         )
#    1343
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2209
#    2210         """
# -> 2211         with self._contextual_connect() as conn:
#    2212             return conn.run_callable(callable_, *args, **kwargs)
#    2213
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338             if connection is None:
#    2339                 Connection._handle_dbapi_exception_noconnection(
# -> 2340                     e, dialect, self
#    2341                 )
#    2342             else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582         elif should_wrap:
#    1583             util.raise_(
# -> 1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#    1586         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#      72         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#      72         else:
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     506     def connect(self, *cargs, **cparams):
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#     510     def create_connect_args(self, url):
#
# C:\Users\petej\Anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "<pg_user>"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)
